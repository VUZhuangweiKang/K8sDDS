# %%
# encoding: utf-8
# Author: Zhuangwei Kang
# %matplotlib inline
import matplotlib.pyplot as plt
from datapsr import *
import numpy as np

# %%
plugins = ['flannel-hostgw-udp', 'flannel-vxlan-udp', 'kube-router-udp', 'weavenet-udp', 'weavenet-udp-encryption', 'weavenet-udp-dds-secure', 'hostnetwork-udp']

# plugins = ['flannel-hostgw-tcp', 'flannel-vxlan-tcp', 'kube-router-tcp', 'weavenet-tcp', 'weavenet-tcp-encryption', 'hostnetwork-tcp']

# plugins = ['flannel-hostgw-udp', 'flannel-hostgw-tcp', 'flannel-vxlan-udp', 'flannel-vxlan-tcp', 'kube-router-udp', 'kube-router-tcp', \
#            'weavenet-udp', 'weavenet-tcp', 'weavenet-udp-encryption', 'hostnetwork-udp',  'hostnetwork-tcp']

# %%
# dataLen test
data_len_test = range(6)
throughput_perf, latency_perf = load_data(data_len_test, plugins)
throughput_perf.to_csv('tmp.csv')
all_colors = ['C%d' %c for c in range(10)]

data_len = [64, 256, 1024, 4096, 16384, 63000]
x = np.arange(6)
total_width, n = 0.8, len(plugins)
width = total_width / n
# x = x - (total_width - width) / 2

plt.xticks(range(len(data_len)), data_len, rotation=0)
plt.ylim(0, 100)
cell_text = []
for i, cni in enumerate(plugins):
    thr = throughput_perf[throughput_perf['cni'] == cni]['mbps(ave)']
    cell_text.append(['%.1f' % x for x in thr])
    plt.plot(x, thr, label=cni, marker='*', color=all_colors[i])

# Add a table at the bottom of the axes
the_table = plt.table(cellText=cell_text,
                      rowLabels=plugins,
                      cellLoc='center',
                      rowColours=all_colors[:len(plugins)],
                      colLabels=data_len,
                      loc='bottom')
the_table.set_fontsize(15)
the_table.scale(1, 1.5)
# Adjust layout to make room for the table:
plt.subplots_adjust(left=0.2, bottom=0.2)

# plt.legend()
# plt.xlabel('dataLen(B)')
plt.ylabel('throughput(Mbps)')
plt.xticks([])
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# sendQueueSize=15 for 63KB and 50 otherwise

# %%
plt.xticks(range(len(data_len)), data_len, rotation=0)
for i, cni in enumerate(plugins):
    cpu = throughput_perf[throughput_perf['cni'] == cni]['cpu']
    plt.plot(x, cpu, label=cni, marker='.')
plt.legend()
plt.xlabel('dataLen(B)')
plt.ylabel('CPU utilization rate(%)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
plt.xticks(range(len(data_len)), data_len, rotation=0)
for i, cni in enumerate(plugins):
    lat = latency_perf[latency_perf['cni'] == cni]['latencyave']
    plt.plot(x, lat, label=cni, marker='.')
plt.legend()
plt.xlabel('dataLen(B)')
plt.ylabel('latency(us)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# reliability test
reliable_test = [6,7]
throughput_perf, latency_perf = load_data(reliable_test, plugins)
x = np.arange(len(plugins))
total_width, n = 0.8, 2
width = total_width / n
x = x - (total_width - width) / 2

labels = ['bestEffort=false', 'bestEffort=true']
plt.xticks(range(len(plugins)), plugins, rotation=90)
for i, t in enumerate(reliable_test):
    thr = throughput_perf[throughput_perf['test'] == t]['mbps(ave)']
    plt.bar(x + i*width, thr, label=labels[i], width=width)
plt.legend()
plt.xlabel('cni')
plt.ylabel('throughput(Mbps)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# reliability test
plt.xticks(range(len(plugins)), plugins, rotation=90)
for i, t in enumerate(reliable_test):
    lat = latency_perf[latency_perf['test'] == t]['90%']
    plt.bar(x + i*width, lat, label=labels[i], width=width)
plt.legend()
plt.xlabel('cni')
plt.ylabel('90th latency(us)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# reliability test
plt.xticks(range(len(plugins)), plugins, rotation=90)
for i, t in enumerate(reliable_test):
    thr = throughput_perf[throughput_perf['test'] == t]['lost']
    plt.bar(x + i*width, thr, label=labels[i], width=width)
plt.legend()
plt.xlabel('cni')
plt.ylabel('lost rate(%)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# numSubscriber unicast test
numsub_test = [6, 8, 9, 10]
throughput_perf, latency_perf = load_data(numsub_test, plugins)

num_subs = [1,2,4,8]
x = np.arange(4)
total_width, n = 0.8, len(plugins)
width = total_width / n
# x = x - (total_width - width) / 2

plt.xticks(x, num_subs, rotation=0)
for i, cni in enumerate(plugins):
    thr = throughput_perf[throughput_perf['cni'] == cni]['mbps(ave)']
    plt.plot(x, thr, label=cni, marker='.')
plt.legend()
plt.xlabel('numSubscribers')
plt.ylabel('unicast throughput(Mbps)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# numSubscriber unicast test
plt.xticks(x, num_subs, rotation=0)
for i, cni in enumerate(plugins):
    lat = latency_perf[latency_perf['cni'] == cni]['90%']
    plt.plot(x, lat, label=cni, marker='.')
plt.legend()
plt.xlabel('numSubscribers')
plt.ylabel('90th latency(us)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# batching test
batch_test = [6, 11]
throughput_perf, latency_perf = load_data(batch_test, plugins)

x = np.arange(len(plugins))
total_width, n = 0.8, 2
width = total_width / n
x = x - (total_width - width) / 2

labels = ['batching=false', 'batching=true']
plt.xticks(range(len(plugins)), plugins, rotation=90)
plt.ylim(0, 100)
for i, t in enumerate(batch_test):
    thr = throughput_perf[throughput_perf['test'] == t]['mbps(ave)']
    plt.bar(x + i*width, thr, label=labels[i], width=width)
plt.grid(axis='y')
plt.legend()
plt.xlabel('cni')
plt.ylabel('throughput(Mbps)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
multicast_plugins = ['weavenet-udp', 'weavenet-udp-encryption', 'hostnetwork-udp', 'weavenet-tcp', 'hostnetwork-tcp']

# %%
# multicast test
multicast_test = [12,13,14,15]
throughput_perf, latency_perf = load_data(multicast_test,  multicast_plugins)

num_subs = [1,2,4,8]
x = np.arange(4)
total_width, n = 0.8, len(plugins)
width = total_width / n
# x = x - (total_width - width) / 2

plt.xticks(x, num_subs, rotation=0)
for i, cni in enumerate(multicast_plugins):
    thr = throughput_perf[throughput_perf['cni'] == cni]['mbps(ave)']
    plt.plot(x, thr, label=cni, marker='.')
plt.legend()
plt.xlabel('numSubscribers')
plt.ylabel('multicast throughput(Mbps)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()

# %%
# multicast test
multicast_test = [12,13,14,15]
throughput_perf, latency_perf = load_data(multicast_test,  multicast_plugins)

num_subs = [1,2,4,8]
x = np.arange(4)
total_width, n = 0.8, len(plugins)
width = total_width / n
# x = x - (total_width - width) / 2

plt.xticks(x, num_subs, rotation=0)
for i, cni in enumerate(multicast_plugins):
    thr = latency_perf[throughput_perf['cni'] == cni]['90%']
    plt.plot(x, thr, label=cni, marker='.')
plt.legend()
plt.xlabel('numSubscribers')
plt.ylabel('90th latency(us)')
plt.rc('axes', axisbelow=True)
plt.grid(axis='y', linestyle=':')
plt.show()
